# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline
x = np.arange(0, 10, 0.1)

f, ax = plt.subplots()
ax.plot(x, np.sin(x));

f.savefig('figure.pdf')

# %%
f.savefig('figure_300.png', dpi=300) #save as png with resolution adjusted

# %%
! dir figure.pdf
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 0C1B-B3C1
#
#  Directory of C:\Users\Luwi\Desktop\myapp\mynewapp
#
# 28/07/2020  14:48             7.671 figure.pdf
#                1 File(s)          7.671 bytes
#                0 Dir(s)  13.838.172.160 bytes free

# %%
! dir -lh figure*.png
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 0C1B-B3C1
#
#  Directory of C:\Users\Luwi\Desktop\myapp\mynewapp
#
#
#  Directory of C:\Users\Luwi\Desktop\myapp\mynewapp
#
# 28/07/2020  14:49            88.651 figure_300.png
#                1 File(s)         88.651 bytes
#                0 Dir(s)  13.839.413.248 bytes free

# %%
f.canvas.get_supported_filetypes() #supported files you can save plot as
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
#defining the size of your image inches
f, ax = plt.subplots()

print('Default size:', f.get_size_inches() * 2.54)

f.set_size_inches(10 / 2.54, 5 / 2.54)

ax.plot(x, np.sin(x));

print('Manually set size:', f.get_size_inches() * 2.54)
# Out:
# Default size: [15.24 10.16]
# Manually set size: [10.  5.]

# %%
#changing displayed size without changing saved file
default_dpi = mpl.rcParams['figure.dpi']
default_dpi #original
# Out:
# 72.0

# %%
mpl.rcParams['figure.dpi'] = 50
f, ax = plt.subplots()
ax.plot(x, np.sin(x));
